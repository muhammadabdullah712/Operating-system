# %%
from pptx import Presentation
from pptx.util import Inches

# Create a presentation object
prs = Presentation()

# Slide 1: Title Slide
slide_1 = prs.slides.add_slide(prs.slide_layouts[0])
title = slide_1.shapes.title
subtitle = slide_1.placeholders[1]

title.text = "Personal Marketing Plan"
subtitle.text = "Your Name\nDate: June 5, 2024"

# Slide 2: Introduction
slide_2 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_2.shapes.title
content = slide_2.placeholders[1]

title.text = "Introduction"
content.text = "Briefly introduce yourself and the purpose of your Personal Marketing Plan."

# Slide 3: Mission Statement / Goal
slide_3 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_3.shapes.title
content = slide_3.placeholders[1]

title.text = "Mission Statement / Goal"
content.text = ("I aspire to become a leading software engineer specializing in artificial intelligence and machine learning.\n"
                "My goal is to develop innovative solutions that solve real-world problems and improve quality of life globally.")

# Slide 4: Unique Selling Proposition (USP)
slide_4 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_4.shapes.title
content = slide_4.placeholders[1]

title.text = "Unique Selling Proposition"
content.text = ("Blending strong technical expertise with excellent problem-solving skills and a collaborative mindset.\n"
                "Proven track record of leading projects from conception to completion.\n"
                "Passion for continuous learning and adaptability to new technologies.")

# Slide 5: Audience / Target Markets
slide_5 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_5.shapes.title
content = slide_5.placeholders[1]

title.text = "Audience / Target Markets"
content.text = ("Tech companies, startups, and research institutions focused on AI and machine learning.\n"
                "Hiring managers, team leaders, and decision-makers in these organizations.\n"
                "Professional networks and communities in AI and tech innovation.")

# Slide 6: Strategy / Plan of Attack
slide_6 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_6.shapes.title
content = slide_6.placeholders[1]

title.text = "Strategy / Plan of Attack"
content.text = ("Where to Find Audience:\n"
                "- Professional networking platforms (LinkedIn)\n"
                "- Industry conferences and seminars\n"
                "- Online AI and ML communities\n\n"
                "How to Communicate:\n"
                "- Regular LinkedIn updates and engagement\n"
                "- Participation in conferences and webinars\n"
                "- Contributions to forums, blogs, and publications\n"
                "- Direct outreach to recruiters and hiring managers")

# Slide 7: Implementation Plan
slide_7 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_7.shapes.title
content = slide_7.placeholders[1]

title.text = "Implementation Plan"
content.text = ("Actions:\n"
                "- Update LinkedIn profile weekly\n"
                "- Attend one conference/webinar quarterly\n"
                "- Publish an AI-related article bi-monthly\n"
                "- Network bi-weekly\n\n"
                "Resources Needed:\n"
                "- Professional networking sites, conference tickets, blog account, time\n\n"
                "Potential Obstacles:\n"
                "- Time management, maintaining motivation, keeping up with industry changes")

# Slide 8: Re-evaluation Plan
slide_8 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_8.shapes.title
content = slide_8.placeholders[1]

title.text = "Re-evaluation Plan"
content.text = ("Metrics for Success:\n"
                "- LinkedIn profile views, connection requests, engagement on posts\n"
                "- Responses and feedback from employers and peers\n\n"
                "Adjustments:\n"
                "- Seek feedback regularly\n"
                "- Explore new networking opportunities\n"
                "- Adjust content strategy based on engagement data\n"
                "- Experiment with different formats (videos, podcasts)\n"
                "- Collaborate with other professionals")

# Slide 9: Conclusion
slide_9 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_9.shapes.title
content = slide_9.placeholders[1]

title.text = "Conclusion"
content.text = ("Recap of the key points.\n"
                "Final thoughts on the importance of a Personal Marketing Plan.\n"
                "Invitation for questions and discussion.")

# Slide 10: Q&A
slide_10 = prs.slides.add_slide(prs.slide_layouts[1])
title = slide_10.shapes.title
content = slide_10.placeholders[1]

title.text = "Q&A"
content.text = "Invite the audience to ask questions and engage in discussion."

# Save the presentation
ppt_path = "/mnt/data/Personal_Marketing_Plan_Presentation.pptx"
prs.save(ppt_path)

ppt_path
# Attempting to save the presentation again due to an error
ppt_path = "/mnt/data/Personal_Marketing_Plan_Presentation.pptx"
prs.save(ppt_path)

ppt_path
# Retry saving the presentation
ppt_path_retry = "/mnt/data/Personal_Marketing_Plan_Presentation_Retry.pptx"
prs.save(ppt_path_retry)

ppt_path_retry
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pptx import Presentation
#       2 from pptx.util import Inches
#       4 # Create a presentation object
#
# ModuleNotFoundError: No module named 'pptx'
